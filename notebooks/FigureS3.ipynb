# %% [markdown]
# # Figure S3 — Predicted cell type abundance agrees with independent markers
#
# Regenerates **Figure S3** from the cached analysis outputs in `figures/paper/cache/`. No GPU, trained model, or whole-slide image is required.
#
# Source: `figures/paper/s4_abundance_plot.py`

# %%
import os, sys, subprocess
from IPython.display import Image, display
# repo root = parent of this notebooks/ directory
ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
os.environ["HNSC_ROOT"] = ROOT
print("HNSC_ROOT =", ROOT)
# Out:
# HNSC_ROOT = /path/to/HNSCC-CellType-Expression-HE

# %%
r = subprocess.run([sys.executable, "figures/paper/s4_abundance_plot.py"], cwd=ROOT,
                   env={**os.environ, "HNSC_ROOT": ROOT},
                   capture_output=True, text=True)
print((r.stdout or r.stderr).strip()[-800:])
assert r.returncode == 0, "script failed"
# Out:
# saved S4_abundance
# marker验证: {'Fibroblast': (np.float64(0.48), np.float64(0.46)), 'Macrophage': (np.float64(0.42), np.float64(0.39)), 'B cell': (np.float64(0.38), np.float64(0.45)), 'Malignant': (np.float64(0.37), np.float64(0.26)), 'Dendritic': (np.float64(0.2), np.float64(0.13)), 'T cell': (np.float64(0.05), np.float64(0.03)), 'Endothelial': (np.float64(-0.0), np.float64(0.07)), 'Mast': (np.float64(0.0), np.float64(-0.08))}

# %%
display(Image(filename=os.path.join(ROOT, "figures/paper/S4_abundance.png")))
