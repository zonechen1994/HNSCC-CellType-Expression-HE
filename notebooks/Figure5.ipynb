# %% [markdown]
# # Figure 5 — The model resolves pathway activity one cell type at a time
#
# Regenerates **Figure 5** from the cached analysis outputs in `figures/paper/cache/`. No GPU, trained model, or whole-slide image is required.
#
# Source: `figures/paper/fig5_gsea_main.py`

# %%
import os, sys, subprocess
from IPython.display import Image, display
# repo root = parent of this notebooks/ directory
ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
os.environ["HNSC_ROOT"] = ROOT
print("HNSC_ROOT =", ROOT)
# Out:
# HNSC_ROOT = /data1/zqchen/npo_61/HNSC_code

# %%
r = subprocess.run([sys.executable, "figures/paper/fig5_gsea_main.py"], cwd=ROOT,
                   env={**os.environ, "HNSC_ROOT": ROOT},
                   capture_output=True, text=True)
print((r.stdout or r.stderr).strip()[-800:])
assert r.returncode == 0, "script failed"
# Out:
# saved Fig5_gsea_main | 24 pathways x 8 cell types | 折间 Spearman 0.987 (0.975-0.996)

# %%
display(Image(filename=os.path.join(ROOT, "figures/paper/Fig5_gsea_main.png")))
